# %%
import pandas as pd
import numpy as np
import json

from nltk.tokenize import wordpunct_tokenize
from models import *
from utils import *
from fuzzy_match import match

from pymorphy2 import MorphAnalyzer

# %%
pd.options.display.max_rows = 1000

# %%
vocab, w2v = load_vectors('vectors/MS_w2v_vectors.txt')
_, fasttext = load_vectors('vectors/MS_fasttext_vectors.txt')

# %%
len(vocab)
# Out:
# 256515

# %%
class MultScler():

    def __init__(self, text, vocab, w2v, fasttext):
        
        self.text = text
        self.data = pd.DataFrame(wordpunct_tokenize(text.lower()), columns = ['token'])
        
        self.dmd_model = DMDtagger(embedding_dim = 100, hidden_dim = 128, char_vocab_size = 174, tagset_size = 3)
        self.dmd_model.load_state_dict(torch.load('model_dicts/DMD_best_model_state_dict.pth',
                                                   map_location=torch.device('cpu')))
        self.dmd_model.eval()
        
        self.intake_model = Intaketagger(embeddings = w2v, embedding_dim = 300, hidden_dim = 256, tagset_size = 3)
        self.intake_model.load_state_dict(torch.load('model_dicts/INTAKE_best_model_state_dict.pth',
                                                   map_location=torch.device('cpu')))
        self.intake_model.eval()
        
        self.adr_model =  ADRtagger(embeddings = torch.cat((w2v, fasttext), 1), embedding_dim = 600,
                                    hidden_dim = 256, tagset_size = 27)
        self.adr_model.load_state_dict(torch.load('model_dicts/ADR_best_model_state_dict.pth',
                                                   map_location=torch.device('cpu')))
        self.adr_model.eval()
        
        self.link_model = Linktagger(embeddings = torch.cat((w2v, fasttext), 1), embedding_dim = 600,
                                     hidden_dim = 256, tagset_size = 2)
        
        self.link_model.load_state_dict(torch.load('model_dicts/LINK_best_model_state_dict.pth',
                                                   map_location=torch.device('cpu')))
        self.link_model.eval()
        
        self.token_to_ind = vocab
        self.w2v = w2v
        self.fasttext = fasttext
        
        self.char_to_ind = load_json('json/char_to_ind.json')
        self.dmd_to_ind = load_json('json/dmd_to_ind.json')
        self.ind_to_dmd = {v:k for k, v in self.dmd_to_ind.items()}
        self.int_label_to_ind = load_json('json/int_label_to_ind.json')
        self.ind_to_int_label = {v:k for k, v in self.int_label_to_ind.items()}
        self.lex_to_ind = load_json('json/lex_to_ind.json')
        self.adr_to_ind = load_json('json/adr_to_ind.json')
        self.ind_to_adr = {v:k for k, v in self.adr_to_ind.items()}
        
        self.dmd_recovery_dict = load_json('json/dmd_recovery_dict.json')
        
        
        self.verbs = read_lexicon('lex/Verbs.txt')
        self.adrs = read_lexicon('lex/Adrs.txt')
        self.symptoms = read_lexicon('lex/Symptoms.txt')
        self.anatomy = read_lexicon('lex/Anatomy.txt')
        
        self.morph = MorphAnalyzer()
    
    def assign_tag(self, norms):
        if norms & self.anatomy:
            return 'ANATOMY'
        elif norms & self.symptoms:
            return 'SYMPTOM'
        elif norms & self.verbs:
            return 'VERB'
        elif norms & self.adrs:
            return 'ADR'
        else:
            return 'O'
    
    def add_dmd_tags(self):
        tokens = self.data['token']
        chars = [[char for char in word] for word in tokens]
        chars = [[self.char_to_ind[char] for char in word] for word in tokens]
        padded_text = []
        for word in chars:
            word = word[:12]        
            word += [0] * (12 - len(word))
            padded_text.append(word)
        padded_text = [padded_text]
        chars = torch.tensor(padded_text).long()
        with torch.no_grad():
            pred = self.dmd_model(chars)
        pred = pred.squeeze(0)
        pred = np.argmax(pred.numpy(), axis=1)
        pred = [self.ind_to_dmd[tag] for tag in pred]
        self.data['dmd_tag'] = pred
        
    def add_lex_tags(self):
        self.data['norm'] = self.data['token'].apply(lambda x: all_norms(x, self.morph))
        self.data['lex_tag'] = self.data['norm'].apply(self.assign_tag)
        self.data = self.data.drop(columns=['norm'])
    
    def prepare_data(self):
        self.add_dmd_tags()
        self.add_lex_tags()
        
    def define_intakes(self):
        tokens = self.data['token']
        tokens = [self.token_to_ind[token] for token in tokens]
        tokens = torch.tensor([tokens]).long()
        dmd_tags = self.data['dmd_tag']
        dmd_tags = [self.dmd_to_ind[dmd] for dmd in dmd_tags]
        dmd_tags = torch.tensor([dmd_tags]).long()
        with torch.no_grad():
            pred = self.intake_model(tokens, dmd_tags)
        pred = pred.squeeze(0)
        pred = np.argmax(pred.numpy(), axis=1)
        pred = [self.ind_to_int_label[pr] for pr in pred]
        self.data['label'] = pred
    
    def create_dmd_json(self):
        self.intake_cases = create_dmd_json(self.data, self.dmd_recovery_dict)
    
    def define_adrs(self):
        tokens = self.data['token']
        tokens = [self.token_to_ind[token] for token in tokens]
        tokens = torch.tensor([tokens]).long()
        lex_tags = self.data['lex_tag']
        lex_tags = [self.lex_to_ind[tag] for tag in lex_tags]
        lex_tags = torch.tensor([lex_tags]).long()
        with torch.no_grad():
            pred = self.adr_model(tokens, lex_tags)
        pred = pred.squeeze(0)
        pred = np.argmax(pred.numpy(), axis=1)
        pred = [self.ind_to_adr[pr] for pr in pred]
        self.data['adr_label'] = pred
        
    def add_adr_tags(self):
        self.data['adr_tag'] = 0
        self.data.loc[self.data['adr_label'] != 'O', 'adr_tag'] = 1
    
    def add_drug_tags(self):
        self.data['drug_tag'] = 0
        self.data.loc[self.data['dmd_tag'] != 'O', 'drug_tag'] = 2    
        
        
    def link_adrs(self):
        for i in range(len(self.intake_cases)):
            cur_dmd_inds = self.intake_cases[i]['inds']
            self.data.iloc[cur_dmd_inds, self.data.columns.get_loc('drug_tag')] = 1
            
            tokens = self.data['token']
            tokens = [self.token_to_ind[token] for token in tokens]
            tokens = torch.tensor([tokens]).long()
            
            adr_tags = self.data['adr_tag']
            adr_tags = torch.tensor([adr_tags]).long()
            
            drug_tags = self.data['drug_tag']
            drug_tags = torch.tensor([drug_tags]).long()
            with torch.no_grad():
                pred = self.link_model(tokens, adr_tags, drug_tags)
            pred = pred.squeeze(0)
            pred = np.argmax(pred.numpy(), axis=1)
            self.intake_cases[i]['adr_inds'] = np.nonzero(pred)[0].tolist()
            
            self.data.loc[self.data['drug_tag'] != 0, 'drug_tag'] = 2
    
    def add_adrs_to_dmd_json(self):
        for i in range(len(self.intake_cases)):
            adrs_dict = prepare_all_adr_tokens(self.intake_cases[i]['adr_inds'], ms.data)
            self.intake_cases[i]['adr_items'] = adrs_dict
    
    def parse_text(self):
        self.prepare_data()
        self.define_intakes()
        self.create_dmd_json()
        if len(self.intake_cases) > 0:
            self.define_adrs()
            self.add_adr_tags()
            self.add_drug_tags()
            self.link_adrs()
            self.add_adrs_to_dmd_json()
        self.print_report()
    
    def replace_text(self, new_text):
        self.text = new_text
        self.data = pd.DataFrame(wordpunct_tokenize(new_text.lower()), columns = ['token'])
        
    def print_report(self):
        print(f'Всего событий приема ПИТРС обнаружено: {len(self.intake_cases)}')
        for i in range(len(self.intake_cases)):
            print('----')
            print(f'{i+1}:')
            print(f"Наименование препарата: {self.intake_cases[i]['full_dmd_name'].capitalize()}\n")
            print('Выявленные побочные эффекты:')
            for j in range(len(self.intake_cases[i]['adr_items'])):
                print(f"{self.intake_cases[i]['adr_items'][j]['class']}: {' '.join(self.intake_cases[i]['adr_items'][j]['tokens'])}")

# %%
text = 'Слоники, всем привет и долгой ремиссии! Подскажите, я принимаю Абаджио, сильно выпадают волосы...'

# %%
ms = MultScler(text, vocab, w2v, fasttext)

# %%
ms.replace_text('Я тоже с такими же вопросами начала колоть коп! проблемы у меня только с глазами. По симптоматике никаких изменений нет(тьфу тьфу тьфу), по мрт буду смотреть в конце лета, волнуюсь немного. Колю коп почти год, сейчас начала аксоглатиран. Из побочек только зуд, но мажу фенистилом, один раз после укола стало сердце как бешеное биться. На время остановила уколы)) сейчас колю дальше чередуя коп и аксо)) думаю у вас будет все нормальножелаю удачи!')

# %%
ms.parse_text()
# Out:
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
# FLS: зуд
# LR: стало сердце как бешеное биться

# %%
ms.data

# %%
ms.data
# Out:
#              token dmd_tag  lex_tag  label  adr_label  adr_tag  drug_tag
# 0                я       O        O      O          O        0         0
# 1             тоже       O        O      O          O        0         0
# 2                с       O        O      O          O        0         0
# 3           такими       O        O      O          O        0         0
# 4               же       O        O      O          O        0         0
# 5        вопросами       O        O      O          O        0         0
# 6           начала       O        O  B-INT          O        0         0
# 7           колоть       O        O  I-INT          O        0         0
# 8              коп       O        O  I-INT          O        0         0
# 9                !       O        O      O          O        0         0
# 10        проблемы       O      ADR      O          O        0         0
# 11               у       O        O      O          O        0         0
# 12            меня       O        O      O          O        0         0
# 13          только       O        O      O          O        0         0
# 14               с       O        O      O          O        0         0
# 15         глазами       O  ANATOMY      O          O        0         0
# 16               .       O        O      O          O        0         0
# 17              по       O        O      O          O        0         0
# 18    симптоматике       O        O      O          O        0         0
# 19         никаких       O        O      O          O        0         0
# 20       изменений       O        O      O          O        0         0
# 21             нет       O        O      O          O        0         0
# 22               (       O        O      O          O        0         0
# 23            тьфу       O        O      O          O        0         0
# 24            тьфу       O        O      O          O        0         0
# 25            тьфу       O        O      O          O        0         0
# 26              ),       O        O      O          O        0         0
# 27              по       O        O      O          O        0         0
# 28             мрт       O        O      O          O        0         0
# 29            буду       O        O      O          O        0         0
# 30        смотреть       O        O      O          O        0         0
# 31               в       O        O      O          O        0         0
# 32           конце       O        O      O          O        0         0
# 33            лета       O        O      O          O        0         0
# 34               ,       O        O      O          O        0         0
# 35        волнуюсь       O        O      O          O        0         0
# 36         немного       O        O      O          O        0         0
# 37               .       O        O      O          O        0         0
# 38            колю       O        O  B-INT          O        0         0
# 39             коп       O        O  I-INT          O        0         0
# 40           почти       O        O  I-INT          O        0         0
# 41             год       O        O  I-INT          O        0         0
# 42               ,       O        O      O          O        0         0
# 43          сейчас       O        O  B-INT          O        0         0
# 44          начала       O        O  I-INT          O        0         0
# 45    аксоглатиран   B-DMD        O  I-INT          O        0         2
# 46               .       O        O      O          O        0         0
# 47              из       O        O      O          O        0         0
# 48         побочек       O      ADR      O          O        0         0
# 49          только       O        O      O          O        0         0
# 50             зуд       O  SYMPTOM      O  B-ADR-FLS        1         0
# 51               ,       O        O      O          O        0         0
# 52              но       O        O      O          O        0         0
# 53            мажу       O        O      O          O        0         0
# 54      фенистилом       O        O      O          O        0         0
# 55               ,       O        O      O          O        0         0
# 56            один       O        O      O          O        0         0
# 57             раз       O        O      O          O        0         0
# 58           после       O        O      O          O        0         0
# 59           укола       O        O      O          O        0         0
# 60           стало       O        O      O   B-ADR-LR        1         0
# 61          сердце       O  ANATOMY      O   I-ADR-LR        1         0
# 62             как       O        O      O   I-ADR-LR        1         0
# 63         бешеное       O        O      O   I-ADR-LR        1         0
# 64          биться       O        O      O   I-ADR-LR        1         0
# 65               .       O        O      O          O        0         0
# 66              на       O        O      O          O        0         0
# 67           время       O        O      O          O        0         0
# 68      остановила       O        O      O          O        0         0
# 69           уколы       O        O      O          O        0         0
# 70              ))       O        O      O          O        0         0
# 71          сейчас       O        O      O          O        0         0
# 72            колю       O        O      O          O        0         0
# 73          дальше       O        O      O          O        0         0
# 74         чередуя       O        O      O          O        0         0
# 75             коп       O        O      O          O        0         0
# 76               и       O        O      O          O        0         0
# 77            аксо   B-DMD        O      O          O        0         2
# 78              ))       O        O      O          O        0         0
# 79           думаю       O        O      O          O        0         0
# 80               у       O        O      O          O        0         0
# 81             вас       O        O      O          O        0         0
# 82           будет       O        O      O          O        0         0
# 83             все       O        O      O          O        0         0
# 84  нормальножелаю       O        O      O          O        0         0
# 85           удачи       O        O      O          O        0         0
# 86               !       O        O      O          O        0         0

# %%
ms.intake_cases
# Out:
# {0: {'dmd_names': ['абаджио'],
#   'inds': [12],
#   'full_dmd_name': 'абаджио',
#   'adr_inds': [15, 16],
#   'adr_items': [{'class': 'IS',
#     'tokens': ['выпадают', 'волосы'],
#     'inds': [15, 16]}]}}

# %%
examples = list(read_lexicon('examples.txt'))

# %%
for i, text in enumerate(examples):
    print(f'--- Пример {i+1} ---')
    print(text)
    print()
    ms.replace_text(text)
    ms.parse_text()
    print()
# Out:
# --- Пример 1 ---
# А мне Авонекс больше нравился, с Синновексом мне стало хуже, и его заменили Тимексоном, уже 2 года колю каждый день, пока тоже нехорошо, но врач отказывается переводить обратно на интерфероны 😡.
#
# Всего событий приема ПИТРС обнаружено: 4
# ----
# 1:
# Наименование препарата: Авонекс
#
# Выявленные побочные эффекты:
# ----
# 2:
# Наименование препарата: Синновекс
#
# Выявленные побочные эффекты:
# ----
# 3:
# Наименование препарата: Тимексон
#
# Выявленные побочные эффекты:
# UNK: нехорошо
# ----
# 4:
# Наименование препарата: Интерферон
#
# Выявленные побочные эффекты:
#
# --- Пример 2 ---
# я принимала.от феморикса волосы сильно выпадывали, а вот от  абаджио и терифлуномида побочек не было.
#
# Всего событий приема ПИТРС обнаружено: 3
# ----
# 1:
# Наименование препарата: Феморикс
#
# Выявленные побочные эффекты:
# IS: волосы сильно выпадывали
# ----
# 2:
# Наименование препарата: Абаджио
#
# Выявленные побочные эффекты:
# NEG: побочек не было
# ----
# 3:
# Наименование препарата: Терифлуномид
#
# Выявленные побочные эффекты:
# NEG: побочек не было
#
# --- Пример 3 ---
# Вчера самостоятельно отменила себе Инфабету 1 б. Сил нет терпеть побочки: мигрень, которая появилась как стала ее колоть и слабость ещё больше, депрессия, потеря веса. Раньше обострений особо не было, колола Копаксон, а тут,ну просто капец. Стала бешеная, плаксивая и слабая. Кто-то отменял самостоятельно? Спасибо за советы
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Инфибета
#
# Выявленные побочные эффекты:
# NEG: потеря веса
# ----
# 2:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# NEG: потеря веса
#
# --- Пример 4 ---
# Я год колола Копаксон/ Тиран и весь год чесалась. А потом началась гигантская крапивница с отеками Квинке и меня сняли с инъекций.
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# LR: крапивница
# A: отеками квинке
# ----
# 2:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
# UNK: чесалась
# LR: крапивница
# A: отеками квинке
#
# --- Пример 5 ---
# Блин у меня от Тизабри волосы прям вытаскиваю пучками... От Копа честно говоря не помню
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Тизабри
#
# Выявленные побочные эффекты:
# IS: волосы
# ----
# 2:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
#
# --- Пример 6 ---
# Я тоже с такими же вопросами начала колоть коп! проблемы у меня только с глазами. По симптоматике никаких изменений нет(тьфу тьфу тьфу), по мрт буду смотреть в конце лета, волнуюсь немного. Колю коп почти год, сейчас начала аксоглатиран. Из побочек только зуд, но мажу фенистилом, один раз после укола стало сердце как бешеное биться. На время остановила уколы)) сейчас колю дальше чередуя коп и аксо)) думаю у вас будет все нормальножелаю удачи!
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
# FLS: зуд
# LR: стало сердце как бешеное биться
#
# --- Пример 7 ---
# Зравствуйте,Вкалываю интерферон бета 1б уже с мая месяца.Всё было ок, побочек, кроме небольшой головной боли и усталости не было.А сегодня через 1,5 часа после укола начало сильно трясти, и где-то около часа трясло, теперь ужасно болит голова, температура 39.Теперь вопрос :может ли спустя два месяца так усилиться эффект от интерферона?
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Интерферон бета-1b
#
# Выявленные побочные эффекты:
# NEG: побочек
# NS: головной боли
# NEG: усталости не было
# FLS: начало сильно трясти
# FLS: трясло
# FLS: болит голова
# FLS: температура 39
# ----
# 2:
# Наименование препарата: Интерферон
#
# Выявленные побочные эффекты:
#
# --- Пример 8 ---
# Сегодня пришла с прогулки (2 часа) и вот уже 5 часов не могу прийти в себя. Усталость жуткая, ноги гудят, даже лежать тяжело. Такое ощущение, что я кирпичи сутки таскала.  Что это? Слабость мыщц или усиленный тонус?  Может быть это спастика? Или побочка от Ребифа?
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Ребиф
#
# Выявленные побочные эффекты:
# NS: усталость жуткая
# MSS: ноги гудят
# QOL: лежать тяжело
# MSS: слабость
#
# --- Пример 9 ---
# понятно. у меня печень шалит от абаджио. тоже послушаю что люди скажут
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Абаджио
#
# Выявленные побочные эффекты:
# DS: печень шалит
#
# --- Пример 10 ---
# Хочу поделиться своим опытом просто может кому поможет)))) мне 21 год диагноз поставили на 25 недели беременности.  Прокесарили, затем перестали работать ноги и права рука , упало зрения сильно назначили Капрксон толку ноль, затем тисабри тоже без эфекта.  И вот банку 1.5 а я только научилась жить с РС . ПРСТОЯННАЯ депрессия, отсутствие аппетита, боли во всем теле... ну разве эта жизнь??? Да жизнь выхода нет, у меня маленький ребенок, съемная квартира, и не кого кто бы нам с себе и помог с ребенком!!! Шло время я пкреапрбывала много чего чтоб жить полноценно и вот в одной из клиник мне посаветрвали белковые питание .купила начала пить, и вот уже 2 месяца не знаю что такое усталость и слабость  ( к слову это не пекламма, и склероз он не лечит) мне стало лучшие.  Да руки , ноги болят плоха я чувствительность ПО я целыми днями бегаю как заведеная а вечером падаю и сплю беспробудно))) удачи всем, и будет здоровы!!!
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# PSY: прстоянная депрессия
# QOL: отсутствие аппетита
# MSS: боли во всем теле
# QOL: усталость
# QOL: слабость
# MSS: ноги болят
# ----
# 2:
# Наименование препарата: Тизабри
#
# Выявленные побочные эффекты:
# PSY: прстоянная депрессия
# QOL: отсутствие аппетита
# MSS: боли во всем теле
# QOL: усталость
# QOL: слабость
# MSS: ноги болят
#
# --- Пример 11 ---
# Лёха, не, у меня тизабри норм протекает, без особых побочных эффектов, а какой другой к примеру?
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Тизабри
#
# Выявленные побочные эффекты:
# NEG: без особых побочных эффектов
#
# --- Пример 12 ---
# Здр, подскажите, пжл,было ли у кого на фоне приема копаксона, сильное выпадение волос. Колю 3 месяца, раньше была на бетафероне. Болею с 2012 года, диагноз установили в 2014г.
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# IS: сильное выпадение волос
# ----
# 2:
# Наименование препарата: Бетаферон
#
# Выявленные побочные эффекты:
#
# --- Пример 13 ---
# Добрый день всем. Принимаю тисабри уже около года. И вот поворот. По всему телу аллергическая реакция. Позвонил в отделение где его капают мне каждый месяц. Рекомендовали супростин. Вроде проходит сыпь. Вопрос у кого-нибудь от тисабри было такое. Спасибо за ответы.
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Тизабри
#
# Выявленные побочные эффекты:
# A: телу
# A: аллергическая реакция
# LR: сыпь
#
# --- Пример 14 ---
# На Генфаксоне собрала почти все побочки( Было на нем плохо, особенно суицидальтные мысли( 1.5 колола. В январе отменили. Ничего сейчас не колю. Состояние отличное. Как здесь говорят, что я "псевдо" склероман)
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Генфаксон
#
# Выявленные побочные эффекты:
# UNK: побочки
# PSY: суицидальтные мысли
#
# --- Пример 15 ---
# Были ли у кого проблемы с сердцем после интерферона? (колю синновекс) Колю с июля, побочки не уходят, а в последнее время после укола с приходом температуры приходит и боль в сердце. И чёрт знает препарат не подходит или склероз с сердцем опять играет.
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата:
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Интерферон бета-1b
#
# Выявленные побочные эффекты:
# UNK: побочные
# FLS: гриппозный трусит жутко
# FLS: температура повышается выше 38 , до 39
# FLS: температуры
# FLS: озноба
# FLS: температура выше 38
# FLS: температура 38 . 6
# FLS: жутко руки
# FLS: нос
# FLS: ноги мёрзнут
# FLS: температуры
# NS: сильная усталость
# FLS: ознобом
# FLS: температурой
# FLS: болит спина
# FLS: температура , около 37 . 2
# MSS: боль в спине
# FLS: температура высокая
# FLS: озноб
# FLS: жар
# FLS: температуру болит
#
# --- Пример 17 ---
# Всем привет) Месяц назад уже писала сюда большой пост, когда пришла сюда новенькой, вот появились еще вопросы, поможете?)1) Кажется, от Тимексона начали сильно лезть волосы. У кого было? Это пройдет? Чем лечили волосики?Показать полностью... 2) Что кому помогает от синяков после инъекций? Использую Троксерутин, но что-то как-то...никак 3) Кто в каких дозах принимает витамин Д? У меня результат 33 (норма 30-100) Слышала от нескольких врачей версию, что при РС хорошо пить 10000МЕ. Всем здоровьяБерегите себя и своих любимых
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Тимексон
#
# Выявленные побочные эффекты:
# IS: начали сильно лезть волосы
#
# --- Пример 18 ---
# Здравствуйте. Были ли у кого-нибудь аллергические реакции на глатирамера ацетат (глатират, тимексон)?У меня была интоксикация. Как итог я задыхалась пол часа, а потом 1.5 часа меня жутко трясло.
#
# Всего событий приема ПИТРС обнаружено: 3
# ----
# 1:
# Наименование препарата: Глатирамера ацетат
#
# Выявленные побочные эффекты:
# UNK: интоксикация
# UNK: задыхалась
# OTHER: жутко трясло
# ----
# 2:
# Наименование препарата: Глатират
#
# Выявленные побочные эффекты:
# OTHER: жутко трясло
# ----
# 3:
# Наименование препарата: Тимексон
#
# Выявленные побочные эффекты:
# UNK: интоксикация
# UNK: задыхалась
# OTHER: жутко трясло
#
# --- Пример 19 ---
# Доброе утро! В очередной раз словила гиппопотама(гриппоподобный синдром). Колю ребиф. Заметила, что не стоит колоть на голодный желудок. Подскажите, пожалуйста, на вашем опыте, какие еще факторы могут спровоцировать визит гиппопотама? Очень уж неприятные ощущения..
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Ребиф
#
# Выявленные побочные эффекты:
# FLS: гриппоподобный синдром
#
# --- Пример 20 ---
# Что закупили, то и будут давать, разве у нас есть выбор?) Меня после синновекса перевели на ребиф.
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Синновекс
#
# Выявленные побочные эффекты:
# ----
# 2:
# Наименование препарата: Ребиф
#
# Выявленные побочные эффекты:
#
# --- Пример 21 ---
# Добрый день всем. Всех с праздником! Подскажите пожалуйста, может кто знает, после приёма таблеток обаджио сильно выпадают волосы. Что можно сделать?
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Абаджио
#
# Выявленные побочные эффекты:
# IS: сильно выпадают волосы
#
# --- Пример 22 ---
# Всем доброе утро! В августе мне подтвердили диагноз РС, с октября месяца я на аксоглатиране, вроде всё нормально, только места уколов чешутся...А сегодня как обычно сделала укол и мне резко стало плохо: участилось сердцебиение,я вся покраснела, жар, рвотный рефлекс, онемели руки...сейчас полегче,но все равно состояние не очень... у  кого такое было? Что это может быть? Очень испугалась
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
# LR: места уколов чешутся
# CVS: участилось сердцебиение
# OTHER: вся покраснела
# DS: жар
# CVS: рвотный рефлекс
# MSS: онемели руки
#
# --- Пример 23 ---
# У меня так было после интерферона,потом генфаксон, температура 38,7 каждый раз,а через 3 месяца пошла кровь сдавать ,а у меня токсический гепатит,мне его сразу отменили и перевели на аксоглатиран.
#
# Всего событий приема ПИТРС обнаружено: 3
# ----
# 1:
# Наименование препарата: Интерферон
#
# Выявленные побочные эффекты:
# ----
# 2:
# Наименование препарата: Генфаксон
#
# Выявленные побочные эффекты:
# FLS: температура 38 , 7
# ----
# 3:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
#
# --- Пример 24 ---
# Девушка, 21 год. Диагноз поставили 6 лет назад, за это время было три обострения на генфаксоне. Перевели на копаксон, всё стало хорошо. Теперь делаю аксоглатиран. Никогда особо на самочувствие не жаловалась, играю в высшей лиге по волейболу, капитан команды.Захожу в подобные группы и становится очень страшно, хочется плакать.P.s пишу с фейка.
#
# Всего событий приема ПИТРС обнаружено: 3
# ----
# 1:
# Наименование препарата: Генфаксон
#
# Выявленные побочные эффекты:
# ----
# 2:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# ----
# 3:
# Наименование препарата: Аксоглатиран
#
# Выявленные побочные эффекты:
#
# --- Пример 25 ---
# 2 недели как начал колоть инфибету, слабость, тело все ломит, мышцы болят, в некоторых местах покраснения после укола, это нормально просто побочки? И как долго продлится?
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Инфибета
#
# Выявленные побочные эффекты:
# MSS: слабость
# MSS: тело все ломит
# NS: мышцы болят
# LR: покраснения
#
# --- Пример 26 ---
# У меня от глатирана сердцебиение часто за сотку было, с эгилоком не расставалась. Тимексон пока радует)
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Глатират
#
# Выявленные побочные эффекты:
# PSY: сердцебиение
# ----
# 2:
# Наименование препарата: Тимексон
#
# Выявленные побочные эффекты:
#
# --- Пример 27 ---
# меня перевили с Авонекса (сейчас его заменяет Синновекс) на копаксон. Небо и земля. На Авонексе и обострения были, и вечно какие-то недомогания, и гриппоподобный синдром всё время... На копаксоне всё намного лучше. И переносится лучше, реакция только местная (шишки, красные пятна в первое время). Почитайте большую тему про копаксон.
#
# Всего событий приема ПИТРС обнаружено: 3
# ----
# 1:
# Наименование препарата: Авонекс
#
# Выявленные побочные эффекты:
# FLS: гриппоподобный синдром
# ----
# 2:
# Наименование препарата: Синновекс
#
# Выявленные побочные эффекты:
# ----
# 3:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# FLS: гриппоподобный
# LR: шишки
# LR: красные пятна
#
# --- Пример 28 ---
# Доброго времени суток!Расскажите, пожалуйста, может, кто столкнулся с чем-то подобным? С резкой потерей веса. Ну килограмм 20 за полгода... интерферон бета 1б был заменен на синовекс. Сейчас пока все отменили.
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Интерферон бета-1b
#
# Выявленные побочные эффекты:
# OTHER: потерей веса
# ----
# 2:
# Наименование препарата: Синновекс
#
# Выявленные побочные эффекты:
# OTHER: потерей веса
#
# --- Пример 29 ---
# привет всем )))) люди у меня вопрос я колол копаксон 4 года вот как месяц начил ребиф и голова болит сильно в тот день...ужас .... подскажите когда когда правильно колоть утром или вечером ?
#
# Всего событий приема ПИТРС обнаружено: 2
# ----
# 1:
# Наименование препарата: Копаксон
#
# Выявленные побочные эффекты:
# ----
# 2:
# Наименование препарата: Ребиф
#
# Выявленные побочные эффекты:
# FLS: голова болит
#
# --- Пример 30 ---
# Ребзя привет, нужен совет. Я розовый слон (рс) с 17 лет... Мне 21. Замужем не была , детей не рожала. С выявлением болезни колола Синновекс в неделю 1 раз. Обострений как таковых не было. Из побочек: Первые 2 недели состояние будто болею гриппом. И депрессия , жуткая депрессия. Но в целом не плохо. Колола до 2016 года, а из за отсутствия симптомов РС, перестала колоть вообще. Показать полностью...Недели 2 назад началось обострение.Зрение ухудшилось значительно, асимметрия правой стороны лица, слабая правая нога, потеря фокуса глаз, головокружение.. В интернете у каждого препарата неимоверное количество побочных эффектов. Врач хочет выписать Аксоглатиран (Российский аналог Копаксону), который не очень то и хвалят. Как мне быть ? Попросить выписать тот же Синновекс (в.м) или попробовать новый препарат... Спасибо
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Синновекс
#
# Выявленные побочные эффекты:
# FLS: состояние будто болею гриппом
# PSY: депрессия
# QOL: жуткая депрессия
# MSS: правой стороны лица
# QOL: потеря
# MSS: головокружение
#
# --- Пример 31 ---
# Понимаю несклер . Давление 180/120 это может быть побочка?
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Несклер
#
# Выявленные побочные эффекты:
# CVS: давление 180
#
# --- Пример 32 ---
# генфаксон колется 3 раза в неделю,болючее дерьмо убивающее печень)
#
# Всего событий приема ПИТРС обнаружено: 1
# ----
# 1:
# Наименование препарата: Генфаксон
#
# Выявленные побочные эффекты:
# LR: болючее

# %%
examples
# Out:
# ['А мне Авонекс больше нравился, с Синновексом мне стало хуже, и его заменили Тимексоном, уже 2 года колю каждый день, пока тоже нехорошо, но врач отказывается переводить обратно на интерфероны 😡.',
#  'я принимала.от феморикса волосы сильно выпадывали, а вот от  абаджио и терифлуномида побочек не было.',
#  'Вчера самостоятельно отменила себе Инфабету 1 б. Сил нет терпеть побочки: мигрень, которая появилась как стала ее колоть и слабость ещё больше, депрессия, потеря веса. Раньше обострений особо не было, колола Копаксон, а тут,ну просто капец. Стала бешеная, плаксивая и слабая. Кто-то отменял самостоятельно? Спасибо за советы',
#  'Я год колола Копаксон/ Тиран и весь год чесалась. А потом началась гигантская крапивница с отеками Квинке и меня сняли с инъекций.',
#  'Блин у меня от Тизабри волосы прям вытаскиваю пучками... От Копа честно говоря не помню',
#  'Я тоже с такими же вопросами начала колоть коп! проблемы у меня только с глазами. По симптоматике никаких изменений нет(тьфу тьфу тьфу), по мрт буду смотреть в конце лета, волнуюсь немного. Колю коп почти год, сейчас начала аксоглатиран. Из побочек только зуд, но мажу фенистилом, один раз после укола стало сердце как бешеное биться. На время остановила уколы)) сейчас колю дальше чередуя коп и аксо)) думаю у вас будет все нормальножелаю удачи!',
#  'Зравствуйте,Вкалываю интерферон бета 1б уже с мая месяца.Всё было ок, побочек, кроме небольшой головной боли и усталости не было.А сегодня через 1,5 часа после укола начало сильно трясти, и где-то около часа трясло, теперь ужасно болит голова, температура 39.Теперь вопрос :может ли спустя два месяца так усилиться эффект от интерферона?',
#  'Что закупили, то и будут давать, разве у нас есть выбор?) Меня после синновекса перевели на ребиф.',
#  'Добрый день всем. Всех с праздником! Подскажите пожалуйста, может кто знает, после приёма таблеток обаджио сильно выпадают волосы. Что можно сделать?',
#  'Всем доброе утро! В августе мне подтвердили диагноз РС, с октября месяца я на аксоглатиране, вроде всё нормально, только места уколов чешутся...А сегодня как обычно сделала укол и мне резко стало плохо: участилось сердцебиение,я вся покраснела, жар, рвотный рефлекс, онемели руки...сейчас полегче,но все равно состояние не очень... у  кого такое было? Что это может быть? Очень испугалась',
#  'У меня так было после интерферона,потом генфаксон, температура 38,7 каждый раз,а через 3 месяца пошла кровь сдавать ,а у меня токсический гепатит,мне его сразу отменили и перевели на аксоглатиран.',
#  'Девушка, 21 год. Диагноз поставили 6 лет назад, за это время было три обострения на генфаксоне. Перевели на копаксон, всё стало хорошо. Теперь делаю аксоглатиран. Никогда особо на самочувствие не жаловалась, играю в высшей лиге по волейболу, капитан команды.Захожу в подобные группы и становится очень страшно, хочется плакать.P.s пишу с фейка.',
#  '2 недели как начал колоть инфибету, слабость, тело все ломит, мышцы болят, в некоторых местах покраснения после укола, это нормально просто побочки? И как долго продлится?',
#  'У меня от глатирана сердцебиение часто за сотку было, с эгилоком не расставалась. Тимексон пока радует)',
#  'меня перевили с Авонекса (сейчас его заменяет Синновекс) на копаксон. Небо и земля. На Авонексе и обострения были, и вечно какие-то недомогания, и гриппоподобный синдром всё время... На копаксоне всё намного лучше. И переносится лучше, реакция только местная (шишки, красные пятна в первое время). Почитайте большую тему про копаксон.',
#  'Доброго времени суток!Расскажите, пожалуйста, может, кто столкнулся с чем-то подобным? С резкой потерей веса. Ну килограмм 20 за полгода... интерферон бета 1б был заменен на синовекс. Сейчас пока все отменили.',
#  'привет всем )))) люди у меня вопрос я колол копаксон 4 года вот как месяц начил ребиф и голова болит сильно в тот день...ужас .... подскажите когда когда правильно колоть утром или вечером ?',
#  'Ребзя привет, нужен совет. Я розовый слон (рс) с 17 лет... Мне 21. Замужем не была , детей не рожала. С выявлением болезни колола Синновекс в неделю 1 раз. Обострений как таковых не было. Из побочек: Первые 2 недели состояние будто болею гриппом. И депрессия , жуткая депрессия. Но в целом не плохо. Колола до 2016 года, а из за отсутствия симптомов РС, перестала колоть вообще. Показать полностью...Недели 2 назад началось обострение.Зрение ухудшилось значительно, асимметрия правой стороны лица, слабая правая нога, потеря фокуса глаз, головокружение.. В интернете у каждого препарата неимоверное количество побочных эффектов. Врач хочет выписать Аксоглатиран (Российский аналог Копаксону), который не очень то и хвалят. Как мне быть ? Попросить выписать тот же Синновекс (в.м) или попробовать новый препарат... Спасибо',
#  'Понимаю несклер . Давление 180/120 это может быть побочка?',
#  'генфаксон колется 3 раза в неделю,болючее дерьмо убивающее печень)']

# %%
ms.parse_text()
# Out:
# Всего событий приема ПИТРС обнаружено: 0

# %%
ms.replace_text(text)
